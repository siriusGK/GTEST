# %%
import pennylane as qml
import matplotlib.pyplot as plt
import numpy as np

# %%
dev=qml.device("default.mixed",wires=4)#making device available for 4 qubits

# %%
qml.Hadamard(wires=0)
# Out:
# H(0)

# %%
qml.RX(np.pi/3,wires=1)
# Out:
# RX(1.0471975511965976, wires=[1])

# %%
qml.Hadamard(wires=2)
qml.Hadamard(wires=3)
# Out:
# H(3)

# %%
qml.SWAP(wires=[0,1])
qml.SWAP(wires=[2,3])
# Out:
# SWAP(wires=[2, 3])
